# %%
import pandas as pd

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %%
# inplace=True modifies the original data
# axis=1 -> y axis 
# axis=0 -> x axis
ufo.drop(['City','Shape Reported'],inplace=True,axis=1)

# %%
ufo.head()
# Out:
#   Colors Reported State             Time
# 0             NaN    NY   6/1/1930 22:00
# 1             NaN    NJ  6/30/1930 20:00
# 2             NaN    CO  2/15/1931 14:00
# 3             NaN    KS   6/1/1931 13:00
# 4             NaN    NY  4/18/1933 19:00

# %%
#deleting rows from data frame
ufo.drop([x for x in range(2,10)],inplace=True,axis=0)

# %%
ufo
# Out:
#       Colors Reported State              Time
# 0                 NaN    NY    6/1/1930 22:00
# 1                 NaN    NJ   6/30/1930 20:00
# 10                NaN    CA   8/15/1937 21:00
# 11                NaN    AL    6/1/1939 20:00
# 12                RED    SC   6/30/1939 20:00
# 13                NaN    IA     7/7/1939 2:00
# 14                NaN    MI    6/1/1941 13:00
# 15                NaN    CA    7/2/1941 11:30
# 16                NaN    CA    2/25/1942 0:00
# 17                NaN    GA    6/1/1942 22:30
# 18                NaN    TN    7/15/1942 1:00
# 19                RED    AK   4/30/1943 23:00
# 20                NaN    NE    6/1/1943 15:00
# 21                NaN    LA    8/15/1943 0:00
# 22                NaN    LA    8/15/1943 0:00
# 23                NaN    KY  10/15/1943 11:00
# 24                NaN    WV    1/1/1944 10:00
# 25                NaN    CA    1/1/1944 12:00
# 26                NaN    WV    1/1/1944 12:00
# ...
